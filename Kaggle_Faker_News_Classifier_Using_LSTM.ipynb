# %% [markdown]
# <a href="https://colab.research.google.com/github/devpatel0005/Kaggle-Faker-News-Classifier-Using-LSTM/blob/main/Kaggle_Faker_News_Classifier_Using_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
